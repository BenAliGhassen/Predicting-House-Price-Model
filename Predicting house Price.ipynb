# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./BostonHousing.csv')

df.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
test = np.array(df)

test.shape
# Out:
# (506, 14)

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df.index[5:9]
# Out:
# RangeIndex(start=5, stop=9, step=1)

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
np.mean(df,axis=0)
# Out:
# crim         3.613524
# zn          11.363636
# indus       11.136779
# chas         0.069170
# nox          0.554695
# rm           6.284634
# age         68.574901
# dis          3.795043
# rad          9.549407
# tax        408.237154
# ptratio     18.455534
# b          356.674032
# lstat       12.653063
# medv        22.532806
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.hist(column='age',figsize=(9,6),bins=20)
# Out:
# array([[<Axes: title={'center': 'age'}>]], dtype=object)

# %%
df.medv.plot(kind="box",figsize=(9,9))
# Out:
# <Axes: >

# %%
index = np.where(df.medv == max(df.medv))

df.iloc[index]
# Out:
#         crim    zn  indus  chas     nox     rm    age     dis  rad  tax  \
# 161  1.46336   0.0  19.58     0  0.6050  7.489   90.8  1.9709    5  403
# 162  1.83377   0.0  19.58     1  0.6050  7.802   98.2  2.0407    5  403
# 163  1.51902   0.0  19.58     1  0.6050  8.375   93.9  2.1620    5  403
# 166  2.01019   0.0  19.58     0  0.6050  7.929   96.2  2.0459    5  403
# 186  0.05602   0.0   2.46     0  0.4880  7.831   53.6  3.1992    3  193
# 195  0.01381  80.0   0.46     0  0.4220  7.875   32.0  5.6484    4  255
# 204  0.02009  95.0   2.68     0  0.4161  8.034   31.9  5.1180    4  224
# 225  0.52693   0.0   6.20     0  0.5040  8.725   83.0  2.8944    8  307
# 257  0.61154  20.0   3.97     0  0.6470  8.704   86.9  1.8010    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297   67.0  2.4216    5  264
# 283  0.01501  90.0   1.21     1  0.4010  7.923   24.8  5.8850    1  198
# 368  4.89822   0.0  18.10     0  0.6310  4.970  100.0  1.3325   24  666
# ...

# %%
import seaborn as sns


sns.regplot(x='lstat',y='medv',data=df)
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
import matplotlib.pyplot as plt

X, Y = df.iloc[::,:13] , df['medv']

# %%
X['medv'] = Y
corr_matrix = X.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE


X, Y = df.iloc[::,:13] , df['medv']

model = LinearRegression ()
model2 = LinearRegression ()
model3 = LinearRegression ()
rfe = RFE(model, n_features_to_select=3)
feat = rfe.fit(X,Y)

print(f"Nb of features selected : {feat.n_features_}")
print(f"selected features :  {feat.support_}")
print(f"ranking :  {feat.ranking_}")
# Out:
# Nb of features selected : 3
# selected features :  [False False False  True  True  True False False False False False False
#  False]
# ranking :  [ 6  8  7  1  1  1 11  3  5  9  2 10  4]

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from sklearn.model_selection import train_test_split

x_one = df[['rm', 'chas', 'nox']]
Y = df['medv']

X_train,X_test,Y_train,Y_test = train_test_split(x_one,Y, train_size=0.7, shuffle=True)

model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,Y_test)
# Out:
# 0.5208240351243332

# %%
from sklearn.metrics import mean_absolute_error ,mean_squared_error as mse

y_true = df['medv'].iloc[:30]
x_test = df[['rm', 'chas', 'nox']].iloc[:30]

# %%
y_pred = model.predict(x_test)

meanErr = mse(y_true, y_pred)

meanErr
# Out:
# 14.98740752266092

# %%
mae = mean_absolute_error(y_true, y_pred)

mae
# Out:
# 3.3199909637007403

# %%
from sklearn.model_selection import train_test_split

x_two = df[['rm', 'ptratio', 'lstat']]
Y = df['medv']

X_train,X_test,Y_train,Y_test = train_test_split(x_two,Y, train_size=0.7, shuffle=True)

model2.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
model2.score(X_test,Y_test)
# Out:
# 0.6286091228968298

# %%
y_true = df['medv'].iloc[:30]
x_test = df[['rm', 'ptratio', 'lstat']].iloc[:30]

y_pred = model2.predict(x_test)

meanErr = mse(y_true, y_pred)

meanErr
# Out:
# 9.541745984994675

# %%
mae = mean_absolute_error(y_true, y_pred)

mae
# Out:
# 2.317878565352453

# %%
from sklearn.model_selection import train_test_split

x_one = df[['rm', 'chas', 'nox','ptratio','lstat']]
Y = df['medv']

X_train,X_test,Y_train,Y_test = train_test_split(x_one,Y, train_size=0.7, shuffle=True)

model3.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_true = df['medv'].iloc[:30]
x_test = df[['rm', 'chas', 'nox','ptratio','lstat']].iloc[:30]

y_pred = model3.predict(x_test)

meanErr = mse(y_true, y_pred)

meanErr
# Out:
# 9.269451888634547

# %%
y_pred = model3.predict(x_test)

meanErr = mse(y_true, y_pred)

meanErr
# Out:
# 9.269451888634547

# %%
mae = mean_absolute_error(y_true, y_pred)

mae
# Out:
# 2.353224277133754

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt

train_sizes, train_scores, validation_scores = learning_curve(
    model3, X, Y, cv=5, scoring='neg_mean_squared_error')

train_scores_mean = -train_scores.mean(axis=1)
validation_scores_mean = -validation_scores.mean(axis=1)

plt.plot(train_sizes, train_scores_mean, label='Training error')
plt.plot(train_sizes, validation_scores_mean, label='Validation error')
plt.xlabel('Training set size')
plt.ylabel('MSE')
plt.title('Learning Curve')
plt.legend()
plt.show()

# %%
import joblib
joblib.dump(model3, 'Predicting House Price.pkl')
# Out:
# ['Predicting House Price.pkl']
